# %% [markdown]
# **BERNSTEIN**
#
# Ej16 p185

# %%
def Bnf (f, n):
    var('t')
    return sum([binomial(n,p)*f(x=(p/n).n())*(1-t)^(n-p)*t^p for p in srange(n+1)])

def f(x):
    return sin(2*pi*x)
L = []
var('i n')
n = 20
'''for i in srange(1, n+1):
    L.append(plot(Bnf(f, i), (x, 0, 1)))
'''
# %time L.append(plot(Bnf(f, 50), (x, 0, 1)))
L.append(plot(f(x), (x, 0, 1)))
show(sum(L))
# Out:
# CPU times: user 2.87 s, sys: 8 ms, total: 2.88 s
# Wall time: 2.87 s
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Parece que, a mayor n, la diferencia entre B(f)(x) y f(x) es menor, pero no para ciertos x sino para todos en el intervalo [0,1]

# %%
show((f.integrate(x, 0, 0.5)).n())
show((Bnf(f, 9).integrate(x, 0, 0.5)).n())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-bfcf018b2d49> in <module>()
#       1
# ----> 2 show((f.integrate(x, Integer(0), RealNumber('0.5'))).n())
#       3 show((Bnf(f, Integer(9)).integrate(x, Integer(0), RealNumber('0.5'))).n())
#       4
#
# AttributeError: 'function' object has no attribute 'integrate'
