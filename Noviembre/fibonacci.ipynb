# %% [markdown]
# EJERCICIOS TEORIA NUM

# %% [markdown]
# 2

# %%
def fib_rec(m):
    if m==0:
        return 0
    elif m==1:
        return 1
    else:
        return fib_rec(m-1)+fib_rec(m-2)

# %%
def fib_it(m):
    var('i')
    L=[0, 1]
    i=2
    while i<=m:
        L.append(L[i-1] + L[i-2])
        i+=1
    return L[m]

# %%
def ganancia(f):
    g = 6875*2*pi*10^-7*f/sqrt((6875*2*pi*f*10^-7)^2+1)
    return g.n()
var('i')
L=[(i, ganancia(i)) for i in srange (200, 300) if ganancia(i)>0.699]
L
# Out:
# [(227, 0.700136012946390),
#  (228, 0.701703335982803),
#  (229, 0.703260537511820),
#  (230, 0.704807682324200),
#  (231, 0.706344834991619),
#  (232, 0.707872059861870),
#  (233, 0.709389421054205),
#  (234, 0.710896982454858),
#  (235, 0.712394807712710),
#  (236, 0.713882960235110),
#  (237, 0.715361503183857),
#  (238, 0.716830499471313),
#  (239, 0.718290011756681),
#  (240, 0.719740102442406),
#  (241, 0.721180833670730),
#  (242, 0.722612267320374),
#  (243, 0.724034465003363),
#  (244, 0.725447488061974),
#  (245, 0.726851397565815),
#  (246, 0.728246254309035),
#  (247, 0.729632118807650),
#  (248, 0.731009051296991),
#  (249, 0.732377111729277),
#  (250, 0.733736359771294),
#  (251, 0.735086854802193),
#  (252, 0.736428655911398),
#  (253, 0.737761821896620),
#  (254, 0.739086411261977),
#  (255, 0.740402482216223),
#  (256, 0.741710092671069),
#  (257, 0.743009300239608),
#  (258, 0.744300162234838),
#  (259, 0.745582735668277),
#  (260, 0.746857077248668),
# ...
